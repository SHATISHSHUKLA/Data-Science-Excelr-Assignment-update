# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier as KNC

# %%
df=pd.read_csv("/content/glass.csv")
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# min      5.430000    0.000000    0.000000    1.000000
# 25%      8.240000    0.000000    0.000000    1.000000
# 50%      8.600000    0.000000    0.000000    2.000000
# 75%      9.172500    0.000000    0.100000    3.000000
# max     16.190000    3.150000    0.510000    7.000000

# %%
df["Type"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
df["Type"].value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %%
#count plot
import seaborn as sns
from matplotlib import pyplot as plt
plt.figure(figsize=(10,6))
sns.countplot(data=df,x=df["Type"])
plt.grid(True)
plt.title('Count Plot')
plt.show()

# %%
df.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
cor = df.corr(method='pearson')

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ddb08_row0_col0, #T_ddb08_row1_col1, #T_ddb08_row2_col2, #T_ddb08_row3_col3, #T_ddb08_row4_col4, #T_ddb08_row5_col5, #T_ddb08_row6_col6, #T_ddb08_row7_col7, #T_ddb08_row8_col8, #T_ddb08_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ddb08_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ddb08_row0_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_ddb08_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ddb08_row0_col4, #T_ddb08_row1_col8, #T_ddb08_row2_col1, #T_ddb08_row2_col3, #T_ddb08_row2_col6, #T_ddb08_row2_col7, #T_ddb08_row2_col9, #T_ddb08_row4_col0, #T_ddb08_row6_col1, #T_ddb08_row6_col5, #T_ddb08_row9_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ddb08_row0_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_ddb08_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_ddb08_row0_col7, #T_ddb08_row4_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_ddb08_row0_col8 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_ddb08_row0_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_ddb08_row1_col0, #T_ddb08_row7_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_ddb08_row1_col2, #T_ddb08_row2_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_ddb08_row1_col3, #T_ddb08_row5_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_ddb08_row1_col4, #T_ddb08_row9_col6 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_ddb08_row1_col5, #T_ddb08_row9_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ddb08_row1_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ddb08_row1_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_ddb08_row1_col9, #T_ddb08_row9_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_ddb08_row2_col4, #T_ddb08_row2_col5, #T_ddb08_row9_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_ddb08_row2_col8, #T_ddb08_row4_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_ddb08_row3_col0, #T_ddb08_row5_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_ddb08_row3_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_ddb08_row3_col2, #T_ddb08_row6_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_ddb08_row3_col4, #T_ddb08_row7_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_ddb08_row3_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_ddb08_row3_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_ddb08_row3_col7, #T_ddb08_row7_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_ddb08_row3_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ddb08_row3_col9 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_ddb08_row4_col1, #T_ddb08_row4_col6, #T_ddb08_row5_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_ddb08_row4_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_ddb08_row4_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ddb08_row4_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_ddb08_row4_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_ddb08_row5_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_ddb08_row5_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_ddb08_row5_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_ddb08_row5_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ddb08_row5_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_ddb08_row5_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_ddb08_row6_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_ddb08_row6_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ddb08_row6_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ddb08_row6_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_ddb08_row6_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ddb08_row6_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_ddb08_row7_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_ddb08_row7_col2, #T_ddb08_row7_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_ddb08_row7_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_ddb08_row7_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_ddb08_row7_col9 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_ddb08_row8_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_ddb08_row8_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ddb08_row8_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_ddb08_row8_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_ddb08_row8_col4, #T_ddb08_row8_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ddb08_row8_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ddb08_row8_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_ddb08_row8_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_ddb08_row9_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_ddb08_row9_col3 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_ddb08_row9_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_ddb08_row9_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ddb08" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddb08_level0_col0" class="col_heading level0 col0" >RI</th>
#       <th id="T_ddb08_level0_col1" class="col_heading level0 col1" >Na</th>
#       <th id="T_ddb08_level0_col2" class="col_heading level0 col2" >Mg</th>
#       <th id="T_ddb08_level0_col3" class="col_heading level0 col3" >Al</th>
#       <th id="T_ddb08_level0_col4" class="col_heading level0 col4" >Si</th>
#       <th id="T_ddb08_level0_col5" class="col_heading level0 col5" >K</th>
#       <th id="T_ddb08_level0_col6" class="col_heading level0 col6" >Ca</th>
#       <th id="T_ddb08_level0_col7" class="col_heading level0 col7" >Ba</th>
#       <th id="T_ddb08_level0_col8" class="col_heading level0 col8" >Fe</th>
#       <th id="T_ddb08_level0_col9" class="col_heading level0 col9" >Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddb08_level0_row0" class="row_heading level0 row0" >RI</th>
#       <td id="T_ddb08_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ddb08_row0_col1" class="data row0 col1" >-0.191885</td>
#       <td id="T_ddb08_row0_col2" class="data row0 col2" >-0.122274</td>
#       <td id="T_ddb08_row0_col3" class="data row0 col3" >-0.407326</td>
#       <td id="T_ddb08_row0_col4" class="data row0 col4" >-0.542052</td>
#       <td id="T_ddb08_row0_col5" class="data row0 col5" >-0.289833</td>
#       <td id="T_ddb08_row0_col6" class="data row0 col6" >0.810403</td>
#       <td id="T_ddb08_row0_col7" class="data row0 col7" >-0.000386</td>
#       <td id="T_ddb08_row0_col8" class="data row0 col8" >0.143010</td>
#       <td id="T_ddb08_row0_col9" class="data row0 col9" >-0.164237</td>
#     </tr>
#     <tr>
#       <th id="T_ddb08_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_ddb08_row1_col0" class="data row1 col0" >-0.191885</td>
#       <td id="T_ddb08_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ddb08_row1_col2" class="data row1 col2" >-0.273732</td>
#       <td id="T_ddb08_row1_col3" class="data row1 col3" >0.156794</td>
#       <td id="T_ddb08_row1_col4" class="data row1 col4" >-0.069809</td>
#       <td id="T_ddb08_row1_col5" class="data row1 col5" >-0.266087</td>
#       <td id="T_ddb08_row1_col6" class="data row1 col6" >-0.275442</td>
#       <td id="T_ddb08_row1_col7" class="data row1 col7" >0.326603</td>
#       <td id="T_ddb08_row1_col8" class="data row1 col8" >-0.241346</td>
#       <td id="T_ddb08_row1_col9" class="data row1 col9" >0.502898</td>
#     </tr>
#     <tr>
#       <th id="T_ddb08_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_ddb08_row2_col0" class="data row2 col0" >-0.122274</td>
#       <td id="T_ddb08_row2_col1" class="data row2 col1" >-0.273732</td>
#       <td id="T_ddb08_row2_col2" class="data row2 col2" >1.000000</td>

# %% [markdown]
# As seen in the above graph, there is a high correlation exists between some of the variables. We can use PCA to reduce the hight correlated variables

# %%
train,test=train_test_split(df,test_size=0.3,random_state=0)

# %%
acc = []
for i in range(3,50,2):
    neigh = KNC(n_neighbors=i)
    neigh.fit(train.iloc[:,0:9],train.iloc[:,9])
    train_acc = np.mean(neigh.predict(train.iloc[:,0:9])==train.iloc[:,9])
    test_acc = np.mean(neigh.predict(test.iloc[:,0:9])==test.iloc[:,9])
    acc.append([train_acc,test_acc])

# %%
plt.plot(np.arange(3,50,2),[i[0]for i in acc],'bo-')
plt.plot(np.arange(3,50,2),[i[1]for i in acc],'ro-')
plt.legend(['train','test'])

# %%
neigh=KNC(n_neighbors=5)
neigh.fit(train.iloc[:,0:9],train.iloc[:,9])
pred_train= neigh.predict(train.iloc[:,0:9])
train_acc=np.mean(pred_train==train.iloc[:,9])
train_acc
# Out:
# 0.7651006711409396

# %%
pred_test= neigh.predict(test.iloc[:,0:9])
test_acc= np.mean(pred_test == test.iloc[:,9])
test_acc
# Out:
# 0.6615384615384615
